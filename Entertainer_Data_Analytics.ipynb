# %% [markdown]
# <a href="https://colab.research.google.com/github/NeerajKumarReddy040/UnifiedMentor-Projects/blob/main/Entertainer_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import sklearn as sk

# %%
# read the data
data1 = pd.read_csv("/content/Entertainer - Basic Info.csv")
data2 = pd.read_csv("/content/Entertainer - Breakthrough Info.csv")
data3 = pd.read_csv("/content/Entertainer - Last work Info.csv")

# %%
# read data1
data1.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
# total rows and columns
data1.shape
# Out:
# (70, 3)

# %%
# list columns name
column = list(data1)
column
# Out:
# ['Entertainer', 'Gender (traditional)', 'Birth Year']

# %%
# read data2
data2.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
# total rows and columns
data2.shape
# Out:
# (70, 4)

# %%
# list columns name
column = list(data2)
column
# Out:
# ['Entertainer',
#  'Year of Breakthrough/#1 Hit/Award Nomination',
#  'Breakthrough Name',
#  'Year of First Oscar/Grammy/Emmy']

# %%
# read data3
data3.head()
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN

# %%
 data3.shape
# Out:
# (70, 3)

# %%
# list columns name
column = list(data3)
column
# Out:
# ['Entertainer', 'Year of Last Major Work (arguable)', 'Year of Death']

# %% [markdown]
# I will now combine the data

# %%
# Merging dataframes on 'Entertainer'
Alldata = pd.merge(data1, data2, on='Entertainer')
Alldata= pd.merge(Alldata,data3, on='Entertainer')

# Display the combined data
Alldata.head()

# Save the combined data to a CSV file
Alldata.to_csv("Entertainer_Combined_Data.csv", index=False)

# %%
Alldata.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...
